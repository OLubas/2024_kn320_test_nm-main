# %% [markdown]
# ## Завдання на екзамен
# 1. У роботі №1, у проекті 3_project, задати змінну середовища під назвою EXAM та вивести її при виконання програми 3.py
# - результат запуску на скріншоті
# ![](exam1.png)
